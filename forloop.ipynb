# %%
print('1. Create a list of 10 random exam scores ranging from 0 to 100 using list comprehension.')
scores=[]

for i in range(10):
  number=int(input('enter your number : '))
  scores.append(number)
print("finalscore", scores)
# Out:
# 1. Create a list of 10 random exam scores ranging from 0 to 100 using list comprehension.
# enter your number : 14
# enter your number : 15
# enter your number : 16
# enter your number : 17
# enter your number : 18
# enter your number : 19
# enter your number : 14
# enter your number : 25
# enter your number : 26
# enter your number : 28
# finalscore [14, 15, 16, 17, 18, 19, 14, 25, 26, 28]

# %%
print('2. Display each score with its index using the enumerate function.')
score=[23,34,44,54]
for  index,score in enumerate(score):
    print(f'Dispaly score: ', (index,score))
# Out:
# 2. Display each score with its index using the enumerate function.
# Dispaly score:  (0, 23)
# Dispaly score:  (1, 34)
# Dispaly score:  (2, 44)
# Dispaly score:  (3, 54)

# %%
print('3. Find all scores greater than 75 and display them.')

scorelist=[75,85,95,45,55]
for score in scorelist:
    if(score>75):
     print(score)
# Out:
# 3. Find all scores greater than 75 and display them.
# 85
# 95

# %%
print('4.Calculate and display the average score')
scores=[10,20,30,40,50]
averagescore=(sum(scores)/len(scores))
print(f'The average score is :', averagescore)
# Out:
# 4.Calculate and display the average score
# The average score is : 30.0
